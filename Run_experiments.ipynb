# %% [markdown]
# This notebook contains all the experiments that we used in our reproducibility study. Due to high computational resources requirements for some experiments we changed the configuration for them to run in reasonable time. In the comments above each experiment we stated the time required to run it and which parameters to change to run full version. Moreover, since we are running python files in this notebook it is not possible to show the plots in the output cells. Because of that under each experiment we included the code to load the plot containing output of each experiment. Output cells will display logging info from python files.
#
# To run the notebook, activate empty virtual environment with python >3.8 and run cell containing the command "!pip install .". After everything is installed rest of the cells will run without any problems.

# %%
# !pip install .
# Out:
# Processing c:\users\ayior\onedrive - uva\1st semester\3rd block\project
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for lfxai: filename=lfxai-0.1.1-py3-none-any.whl size=33664 sha256=c91da7cd3ce5d4dfa3f3bb05c489b824a5e3658131cff32f0fe72e973a1e9a3c
#   Stored in directory: C:\Users\ayior\AppData\Local\Temp\pip-ephem-wheel-cache-rm8d3gju\wheels\12\e9\bf\0b281cde7e2e39af938dbdbf6e4f31255bcda18a2c9ab953b8
# Successfully built lfxai
# ...
#   Attempting uninstall: lfxai
#     Found existing installation: lfxai 0.1.1
#     Uninstalling lfxai-0.1.1:
#       Successfully uninstalled lfxai-0.1.1
# ...

# %%
import os
from IPython.display import IFrame
os.chdir(r"./experiments")

# %% [markdown]
# ### MNIST Experiments

# %% [markdown]
# #### Consistency Features

# %%
# Approx. time on CPU: 20 mins
# %run mnist.py --name consistency_features
# Out:
# 2023-02-02 01:16:30,645 - INFO - Computing feature importance with Gradient Shap
# 2023-02-02 01:16:36,945 - INFO - Perturbing 5% of the features with Gradient Shap
# 2023-02-02 01:16:43,073 - INFO - Perturbing 10% of the features with Gradient Shap
# 2023-02-02 01:16:53,487 - INFO - Perturbing 20% of the features with Gradient Shap
# 2023-02-02 01:17:47,446 - INFO - Perturbing 50% of the features with Gradient Shap
# 2023-02-02 01:18:40,110 - INFO - Perturbing 80% of the features with Gradient Shap
# 2023-02-02 01:19:49,508 - INFO - Perturbing 100% of the features with Gradient Shap
# 2023-02-02 01:21:06,001 - INFO - Computing feature importance with Integrated Gradients
# 2023-02-02 01:23:02,311 - INFO - Perturbing 5% of the features with Integrated Gradients
# 2023-02-02 01:23:07,718 - INFO - Perturbing 10% of the features with Integrated Gradients
# 2023-02-02 01:23:16,746 - INFO - Perturbing 20% of the features with Integrated Gradients
# ...

# %%
IFrame(r"experiments/results/mnist/consistency_features/mnist_consistency_features.pdf", width=600, height=500)
# Out:
#         <iframe
#             width="600"
#             height="500"
#             src="experiments/results/mnist/consistency_features/mnist_consistency_features.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# #### Consistency Examples

# %%
# 15 mins for size 50
# Default subtrain is 1000, it must be >=50
# %run mnist.py --name consistency_examples --subtrain_size 50
# Out:
# 2023-02-01 15:28:10,797 - INFO - Now fitting autoencoder
# 2023-02-01 15:28:10,837 - INFO - Now fitting Influence Functions explainer
# ...
#  90%|██████████████████████████████████████████████████████████████████▌       | 90/100 [00:17<00:02,  4.66recursion/s]
# ...
# ...
#   0%|          | 0/2500 [00:00<?, ?it/s]
# 2023-02-01 15:43:28,249 - INFO - Now fitting TracIn explainer
# 2023-02-01 15:43:28,269 - INFO - Now fitting SimplEx explainer
# 2023-02-01 15:43:28,847 - INFO - Now fitting DKNN explainer
# 2023-02-01 15:43:28,949 - INFO - Saving results in C:\Users\ayior\OneDrive - UvA\1st Semester\3rd Block\Project\experiments\results\mnist\consistency_examples

# %%
IFrame("experiments/results/mnist/consistency_examples/similarity_rates.pdf")

# %% [markdown]
# #### Roar Test

# %%
# time required to run: 1h 30min
# %run mnist.py --name roar_test
# Out:
# 2023-02-01 16:16:25,175 - INFO - Welcome in the ROAR test experiments
# 2023-02-01 16:16:26,907 - INFO - Computing feature importance with Gradient Shap
# 2023-02-01 16:16:59,374 - INFO - Retraining an autoencoder with 10% pixels masked by Gradient Shap
# 2023-02-01 16:17:50,332 - INFO - Retraining an autoencoder with 20% pixels masked by Gradient Shap
# 2023-02-01 16:19:27,642 - INFO - Retraining an autoencoder with 50% pixels masked by Gradient Shap
# 2023-02-01 16:23:26,350 - INFO - Retraining an autoencoder with 70% pixels masked by Gradient Shap
# 2023-02-01 16:28:52,181 - INFO - Retraining an autoencoder with 100% pixels masked by Gradient Shap
# 2023-02-01 16:45:49,935 - INFO - Computing feature importance with Integrated Gradients
# 2023-02-01 17:03:23,637 - INFO - Retraining an autoencoder with 10% pixels masked by Integrated Gradients
# 2023-02-01 17:04:16,464 - INFO - Retraining an autoencoder with 20% pixels masked by Integrated Gradients
# ...

# %%
IFrame("experiments/results/mnist/roar_test/roar.pdf", width=600, height=500)
# Out:
#         <iframe
#             width="600"
#             height="500"
#             src="experiments/results/mnist/roar_test/roar.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# #### Pretext tasks

# %%
# time required for 'gradient_shap' method: 1 min
# options for method: gradient_shap, integrated_gradients, saliency
# default gradient_shap
# to run different method change parameter 'method' to one of the available options (have in mind that integrated_gradients
# method takes more time to run)
# %run mnist.py --name pretext --n_runs 1 --method gradient_shap
# Out:
# 2023-02-02 17:53:06,107 - INFO - gradient_shap
# 2023-02-02 17:53:06,410 - INFO - Now fitting Reconstruction-ae_run0
# 2023-02-02 17:53:06,419 - INFO - Computing feature importance
# 2023-02-02 17:53:06,421 - INFO - Using method: <captum.attr._core.gradient_shap.GradientShap object at 0x0000025403F5FA00>
# 2023-02-02 17:53:12,852 - INFO - Computing example importance
# 2023-02-02 17:53:13,416 - INFO - Now fitting Denoising-ae_run0
# 2023-02-02 17:53:13,422 - INFO - Computing feature importance
# 2023-02-02 17:53:13,424 - INFO - Using method: <captum.attr._core.gradient_shap.GradientShap object at 0x0000025403FBFEB0>
# 2023-02-02 17:53:19,890 - INFO - Computing example importance
# 2023-02-02 17:53:20,432 - INFO - Now fitting Inpainting-ae_run0
# 2023-02-02 17:53:20,438 - INFO - Computing feature importance
# 2023-02-02 17:53:20,438 - INFO - Using method: <captum.attr._core.gradient_shap.GradientShap object at 0x0000025403F5F5E0>
# ...

# %%
IFrame("experiments/results/mnist/pretext/gradient_shap_saliency_maps_run0.pdf", width=600, height=500)
# Out:
#         <iframe
#             width="600"
#             height="500"
#             src="experiments/results/mnist/pretext/gradient_shap_saliency_maps_run0.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# #### Disentangled VAEs

# %%
# time required for 'gradient_shap' method for 1 run: 25 min
# options for method: gradient_shap, integrated_gradients, saliency
# default gradient_shap
# to run different method change parameter 'method' to one of the available options (have in mind that integrated_gradients
# method takes more time to run)
# to create the boxplot n_runs needs to be increased (it will take more time to run)
# %run mnist.py --name disvae --n_runs 1 --method gradient_shap
# Out:
# 2023-02-02 18:01:01,371 - INFO - gradient_shap
# 2023-02-02 18:01:01,398 - INFO - Creating metrics csv in C:\Users\ayior\OneDrive - UvA\1st Semester\3rd Block\Project\experiments\results\mnist\vae\metrics_gradient_shap.csv
# 2023-02-02 18:01:01,420 - INFO - Now loading Beta-vae_beta1_run1
# 2023-02-02 18:01:01,434 - INFO - Computing feature importance
# 2023-02-02 18:02:18,301 - INFO - Metrics computed
# 2023-02-02 18:02:18,301 - INFO - Model Beta-vae_beta1_run1 	 Pearson Correlation 0.28	Spearman Correlation 0.98	Cosine 0.63	Entropy 0.71	Active Neurons 1.3
# 2023-02-02 18:03:16,281 - INFO - Now loading TC-vae_beta1_run1
# 2023-02-02 18:03:16,312 - INFO - Computing feature importance
# 2023-02-02 18:04:24,822 - INFO - Metrics computed
# 2023-02-02 18:04:24,822 - INFO - Model TC-vae_beta1_run1 	 Pearson Correlation 0.26	Spearman Correlation 0.98	Cosine 0.64	Entropy 0.71	Active Neurons 1.3
# 2023-02-02 18:05:23,027 - INFO - Now loading Beta-vae_beta5_run1
# ...

# %%
# One example:
IFrame("experiments/results/mnist/vae/Beta-vae_beta1_run1_gradient_shap.pdf", width=600, height=500)

# %% [markdown]
# ### ECG5000 Experiments

# %% [markdown]
# #### Consistency Features

# %%
# time required to run: 12 min
# %run ecg5000.py --name consistency_features
# Out:
# 2023-02-01 18:33:59,182 - INFO - Downloading the ECG5000 Dataset.
# 100% [........................................................................] 10614407 / 10614407
# 2023-02-01 18:34:04,480 - INFO - Finished Downloading.
# C:\Users\ayior\anaconda3\envs\env1\lib\site-packages\lfxai\utils\datasets.py:284: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total_df = total_df.append(pd.DataFrame(data))
# C:\Users\ayior\anaconda3\envs\env1\lib\site-packages\lfxai\utils\datasets.py:284: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total_df = total_df.append(pd.DataFrame(data))
# 2023-02-01 18:34:05,485 - INFO - Computing feature importance with Gradient Shap
# 2023-02-01 18:35:00,062 - INFO - Perturbing 5% of the features with Gradient Shap
# ...

# %%
IFrame("experiments/results/ecg5000/consistency_features/ecg5000_consistency_features.pdf", width=600, height=500)
# Out:
#         <iframe
#             width="600"
#             height="500"
#             src="results/ecg5000/consistency_features/ecg5000_consistency_features.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# #### Consistency Examples

# %%
# time required to run: x min
# to run experiments in reasonable time we decreased the size of test dataset for example importance experiment
# to use whole dataset remove the parameter '--subset_size' 
# --subset_size needs to be >50
# %run ecg5000.py --name consistency_examples --subset_size 50
# Out:
# C:\Users\ayior\anaconda3\envs\env1\lib\site-packages\lfxai\utils\datasets.py:284: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total_df = total_df.append(pd.DataFrame(data))
# 2023-02-03 00:17:04,876 - INFO - Fitting autoencoder
# 2023-02-03 00:17:04,903 - INFO - Now fitting Influence Functions explainer
# ...
#  88%|█████████████████████████████████████████████████████████████████         | 88/100 [01:41<00:13,  1.08s/recursion]
# ...
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 50/50 [00:08<00:00,  5.92example/s]
#
# ...
#   0%|          | 0/2500 [00:00<?, ?it/s]
# 2023-02-03 01:55:34,346 - INFO - Now fitting SimplEx explainer
# 2023-02-03 01:55:37,394 - INFO - Now fitting DKNN explainer
# 2023-02-03 01:55:40,532 - INFO - Saving results in C:\Users\ayior\OneDrive - UvA\1st Semester\3rd Block\Project\experiments\results\ecg5000\consistency_examples

# %%
IFrame("experiments/results/ecg5000/consistency_examples/ecg5000_similarity_rates.pdf", width=600, height=500)
# Out:
#         <iframe
#             width="600"
#             height="500"
#             src="experiments/results/ecg5000/consistency_examples/ecg5000_similarity_rates.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### CIFAR-10 Experiments

# %% [markdown]
# #### Consistency Features & Examples

# %%
# time required to run: 10 min
# to run experiments in reasonable time we decreased the size of test dataset for feature importance experiment
# to use whole dataset change parameter 'num_samples' in experiments/simclr_config.yaml file to 0
# %run cifar10.py
# Out:
# C:\Users\ayior\OneDrive - UvA\1st Semester\3rd Block\Project\experiments\cifar10.py:228: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_name="simclr_config.yaml", config_path=str(Path.cwd()))
# C:\Users\ayior\anaconda3\envs\env1\lib\site-packages\hydra\_internal\hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# C:\Users\ayior\anaconda3\envs\env1\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %%
IFrame("experiments/results/cifar10/consistency_examples/cifar10_similarity_rates.pdf", width=600, height=500)
# Out:
#         <iframe
#             width="600"
#             height="500"
#             src="experiments/results/cifar10/consistency_examples/cifar10_similarity_rates.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("experiments/results/cifar10/consistency_features/cifar10_consistency_features.pdf", width=600, height=500)
# Out:
#         <iframe
#             width="600"
#             height="500"
#             src="experiments/results/cifar10/consistency_features/cifar10_consistency_features.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Dsprites Experiments

# %% [markdown]
# #### Disentangled VAEs - feature importance

# %%
# Dsprites experiments
# 3 different betas, 2 different models, 5 runs = 30 models x 1 min = 30 mins
# You can lower the number of runs
# Report plots were obtained with the default test_split which is 0.1 (needs ~30 hours on titan rtx)
# %run dsprites --test_split 0.0001 --n_runs 5
# Out:
# 2023-02-01 19:36:12,788 - INFO - 73
# 2023-02-01 19:36:12,815 - INFO - Now loading Beta-vae_beta1_run1
# 2023-02-01 19:36:17,639 - INFO - Model Beta-vae_beta1_run1 	 Pearson Correlation 0.37	Spearman Correlation 1	Cosine 0.71	Entropy 1.1	Active Neurons 2.1
# 2023-02-01 19:37:35,371 - INFO - Now loading Beta-vae_beta1_run2
# 2023-02-01 19:37:38,770 - INFO - Model Beta-vae_beta1_run2 	 Pearson Correlation 0.36	Spearman Correlation 1	Cosine 0.68	Entropy 1.1	Active Neurons 2
# 2023-02-01 19:38:56,173 - INFO - Now loading Beta-vae_beta1_run3
# 2023-02-01 19:39:00,472 - INFO - Model Beta-vae_beta1_run3 	 Pearson Correlation 0.34	Spearman Correlation 1	Cosine 0.67	Entropy 1.1	Active Neurons 2.1
# 2023-02-01 19:40:11,613 - INFO - Now loading Beta-vae_beta1_run4
# 2023-02-01 19:40:14,402 - INFO - Model Beta-vae_beta1_run4 	 Pearson Correlation 0.29	Spearman Correlation 1	Cosine 0.66	Entropy 1	Active Neurons 2
# 2023-02-01 19:41:26,912 - INFO - Now loading Beta-vae_beta1_run5
# ...

# %%
IFrame("experiments/results/dsprites/vae/Beta-vae_beta1_run1.pdf", width=600, height=500)
# Out:
#         <iframe
#             width="600"
#             height="500"
#             src="experiments/results/dsprites/vae/Beta-vae_beta1_run1.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("experiments/results/dsprites/vae/metric_box_plots.pdf", width=600, height=500)
# Out:
#         <iframe
#             width="600"
#             height="500"
#             src="experiments/results/dsprites/vae/metric_box_plots.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#Fashion MNIST experiments

# %run fashionmnist.py --name consistency_features
# Out:
# ...
#   0%|          | 0/26421880 [00:00<?, ?it/s]
# Extracting C:\Users\ayior\OneDrive - UvA\1st Semester\3rd Block\Project\experiments\data\fashionmnist\FashionMNIST\raw\train-images-idx3-ubyte.gz to C:\Users\ayior\OneDrive - UvA\1st Semester\3rd Block\Project\experiments\data\fashionmnist\FashionMNIST\raw
#
# ...
#   0%|          | 0/29515 [00:00<?, ?it/s]
# Extracting C:\Users\ayior\OneDrive - UvA\1st Semester\3rd Block\Project\experiments\data\fashionmnist\FashionMNIST\raw\train-labels-idx1-ubyte.gz to C:\Users\ayior\OneDrive - UvA\1st Semester\3rd Block\Project\experiments\data\fashionmnist\FashionMNIST\raw
#
# ...
#   0%|          | 0/4422102 [00:00<?, ?it/s]
# Extracting C:\Users\ayior\OneDrive - UvA\1st Semester\3rd Block\Project\experiments\data\fashionmnist\FashionMNIST\raw\t10k-images-idx3-ubyte.gz to C:\Users\ayior\OneDrive - UvA\1st Semester\3rd Block\Project\experiments\data\fashionmnist\FashionMNIST\raw
#
# ...
#   0%|          | 0/5148 [00:00<?, ?it/s]
# ...

# %%
IFrame("experiments/results/fashionmnist/consistency_features/fashion_mnist_consistency_features.pdf", width=600, height=500)
# Out:
#         <iframe
#             width="600"
#             height="500"
#             src="experiments/results/fashionmnist/consistency_features/fashion_mnist_consistency_features.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
